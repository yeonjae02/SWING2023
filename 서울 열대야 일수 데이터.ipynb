# %%
import pandas as pd
import os
os.chdir(r"C:\Users\samsung\Downloads\swing 해커톤\realfiles")

# %%
df = pd.read_csv("서울_열대야_일수데이터.csv", engine = "python",encoding = "CP949")
df.head()
# Out:
#       년  열대야일수
# 0  2002      4
# 1  2003      1
# 2  2004     13
# 3  2005     11
# 4  2006     10

# %%
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 20
plt.rcParams["figure.figsize"] = (30, 10)

# %%
# 그래프 기본 설정
plt.title("서울 열대야 일수")
plt.xlabel("연도")
plt.ylabel("열대야 일수")

plt.xticks(range(2002, 2023), size = 15)
plt.plot(df['년'], df['열대야일수'], label = '열대야 일수')

plt.legend()
