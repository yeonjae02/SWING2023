# %%
import pandas as pd
import os
os.chdir(r"C:\Users\0yeon\SWING 2023\project\data")

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows, Mac일 때는 AppleGothic
matplotlib.rcParams['font.size'] = 15 # 폰트 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시 마이너스 글자가 깨지는 것방지

# %%
df = pd.read_csv("100년간 여름 평균기온.csv", engine = "python",encoding = "CP949")
df.head()
# Out:
#      요소  평균기온(℃)
# 0  1912     23.0
# 1  1913     22.0
# 2  1914     24.2
# 3  1915     23.6
# 4  1916     22.8

# %%
plt.title("The average summer temperature for 100 years")
plt.xlabel('Year')
plt.ylabel("The average temperature")


plt.plot(df['요소'], df['평균기온(℃)'], label="Temperature")
plt.legend(loc='upper left')
plt.savefig('The average summer temperature for 100 years.png', dpi=300)
