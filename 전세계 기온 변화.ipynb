# %%
import pandas as pd
import os
os.chdir(r"C:\Users\thdus\SWING\데이터")

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows, Mac일 때는 AppleGothic
matplotlib.rcParams['font.size'] = 15 # 폰트 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시 마이너스 글자가 깨지는 것방지

# %%
df = pd.read_csv("Global_annual_mean_temp.csv", engine = "python",encoding = "CP949")
df.head()
# Out:
#    Year  No_Smoothing
# 0  1880         -0.17
# 1  1881         -0.09
# 2  1882         -0.11
# 3  1883         -0.18
# 4  1884         -0.28

# %%
plt.title("Global temperature changes")
plt.xlabel("Year")
plt.ylabel("Difference from the avg")

plt.xticks(range(1880,2023,10),size = 10)
plt.plot(df['Year'], df['No_Smoothing'])
